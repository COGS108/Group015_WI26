# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# - Danielle Trinh: Writing – original draft, Writing – review & editing, Software, Visualization
# - Kayne Maniti:  Writing – review & editing
# - Dana Wei: Writing – review & editing, Background research
# - Max Kim: Writing – original draft, Writing – review & editing, Conceptualization
# - Agnes Tang: Writing – review & editing, Methodology

# %% [markdown]
# ## Research Question

# %% [markdown]
# Between 2006 and 2015, do North America, Europe, and Japan differ in their market-share distribution across four genre categories (Action/Competitive, Narrative, Strategy/Cognitive, and Misc) on the PS3, X360, Wii, DS, PSP, and PC platforms, and have these regional differences changed over time?
#
# We use a video game sales dataset containing regional sales information for North America, Europe, and Japan. To focus on a consistent multi-platform generation era and avoid lifecycle distortions across console generations, we restrict the analysis to the years 2006–2015 and to the major overlapping platforms PS3, X360, Wii, DS, PSP, and PC.
#
# We group the original 12 genres into four broader genre categories (Action/Competitive, Narrative, Strategy/Cognitive, and Misc) to reduce dimensionality while preserving interpretability. For each region, year, and platform, we compute genre market share as genre-specific regional sales divided by total regional sales for that platform-year.
#
# We then compare genre-share distributions across regions using statistical inference tests and estimate regression models to evaluate whether the magnitude of regional differences changes over time.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The video game industry is a global market in which games are produced, distributed, and consumed across diverse cultural and economic contexts. A central question in this globalized environment is whether player preferences are converging worldwide or whether they remain shaped by regional tastes, platform ecosystems, and local industry structures. As the industry has expanded, scholars have debated whether players in different regions increasingly gravitate toward similar genres and platforms or whether long‑standing regional identities continue to generate distinct patterns of demand. This tension between global convergence and regional differentiation motivates a closer empirical examination of how video game purchases vary across regions and how those patterns evolve over time.
#
# Prior work has demonstrated that commercial performance varies widely across titles, even within the same release year. Researchers have identified product characteristics, especially platform and genre, as major determinants of sales outcomes. Studies using global sales rankings demonstrate that both platform and genre exert significant influence on units sold, suggesting that hardware ecosystems and content categories shape how games compete in the marketplace (Wang, 2025). In addition, regional sales variables explain further variation in performance, indicating that demand conditions differ meaningfully across geographic markets. These findings motivate a region‑sensitive approach in which regional market characteristics are treated as integral components of explanatory models rather than secondary factors.
#
# Additionally, regional variation in video game consumption is not only cross‑sectional, but also temporally persistent. Studies of long run sales patterns have found that, while some genres attain widespread popularity, regional markets still tend to maintain distinct preferences that reflect cultural tastes and local industry structures (Zhang, 2021). This suggests that differences in the composition of regional game libraries are the result of relatively stable underlying demand conditions, rather than short‑term trends or one‑off blockbuster releases. In other words, regions do not simply converge on the same set of titles. Instead, they continue to favor different mixes of genres and platforms over time, indicating that regional identity and market context play a lasting role in shaping what players choose to buy.
#
# “Predictive Analytics for Video Game Sales” by Rifaz primarily focuses on predictive modeling of sales outcomes rather than on comparative analysis of regional preferences. This prior work shows that global sales outcomes can be predicted with very high accuracy using regional sales data, indicating that regional markets exhibit stable and structured sales patterns that consistently explain global success. However, it treats regions mainly as inputs to prediction rather than as objects of comparison. In particular, it does not examine whether regions systematically differ in their genre preferences after accounting for total market size, nor does it analyze how those differences change over time. This project builds on that analytical foundation but reframes the problem toward comparative and longitudinal analysis, focusing on genre market share by region and year rather than on "The impact of platform on global video game sales" has identified gaming platforms as a key structural factor influencing global video game sales patterns.
#
# Babb, Terry, and Dana (2013) examined worldwide video game sales across major platforms between 2006 and 2011 and found significant differences in sales performance attributable to platform ecosystems rather than individual game attributes alone. Their study showed that Nintendo platforms—particularly the Wii and Nintendo DS—consistently outperformed competing consoles globally, while Microsoft and Sony platforms occupied lower sales tiers. These findings suggest that platform strategy, vertical integration, and regional platform adoption play a central role in shaping observed sales distributions. This work provides an important foundation for our analysis of regional sales differences, particularly in understanding why Japan’s sales distribution diverges from North America and Europe, where non-Nintendo platforms are more dominant.
#
# Taken together, the literature suggests that platform, genre, and region all play important roles in shaping video game consumption, but it leaves open key questions about how regional genre preferences differ, how these differences vary across platforms, and whether they change over time. This project addresses these gaps by analyzing genre market‑share distributions across North America, Europe, and Japan from 2006 to 2015, focusing on the major overlapping platforms of that generation. By grouping genres into four interpretable categories and examining changes across regions and years, this study provides a comparative and longitudinal perspective on regional demand patterns that has been largely absent from prior work. Wang, Z. (2025). Factors Affecting Global Video Game Sales Rankings: Analyzing the Impact of Platform, Genre, and Market Regions. American Journal of Student Research. https://doi.org/10.70251/hyjr2348.337280
#
# Zhang, X. (2021). Evaluation of Game Publishers and Study on the Player Preference Based on the Data from 1980 to 2020 in Video Game Market. 2021 the 8th International Conference on Industrial Engineering and Applications(Europe). https://doi.org/10.1145/3463858.3463870
#
# Rifaz, F. (2025). Predictive Analytics for Video Game Sales [Kaggle Notebook]. Kaggle. https://www.kaggle.com/code/faryalrifaz3374/predictive-analytics-for-video-game-sales/notebook
#
# Babb, J., Terry, N., & Dana, K. (2013). The impact of platform on global video game sales. International Business & Economics Research Journal, 12(10), 1241–1248.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We believe that North America, Europe, and Japan will differ significantly in the market-share distribution across the genres Action/Competitive, Narrative, Strategy/Cognitive, and Misc on the following platforms: PS3, X360, Wii, DS, PSP, and PC. We also believe that the gap in video game sales between these three regions has remained unchanged between 2006 and 2015. This can be seen in the research article on factors that impact global video game sales written by Zilu Wang, regions in North America and the European Union make up the majority of global video game sales, while Japan and other regions make up a smaller percentage, despite having a positive trend in video game sales. There is also a major regional difference in terms of video game genres, as cited from Xiaohan Zhang's research article on player preference, where North American regions and the EU favor action-type genre games, while Japanese players enjoy more moderate games like role-playing and narrative. No changes in the gap between regions in terms of sales occured between 2006 to 2015 based on the predictive analysis created by Faryal Rifaz and edited by Muhammad Tufail, as genres like Platform, Shooting, and Role-playing are the top three genres being sold which favor North American and EU regions.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# 1. Explain what the **ideal** dataset you would want to answer this question. (This should include:
#    1. What variables?
#        * It would need precise variables such as: Game Title, Genre, Platform, Publisher, Release Date (Month/Year), and disaggregated region specific Sales Figures Ideally, it would also distinguish between Digital vs. Physical sales, as digital adoption varies by region.
#    2. How many observations are needed?
#        * The ideal dataset would have tens of thousands of observations to show a variety of games of different niches, not just the popular ones in order to ensure representative samples for each region.
#    3. Who/what/how would these data be collected?
#        * Ideally this data should be collected from the game sales providers from major retailers and digital store front APIs (platforms like Steam, Playstation store, Nintendo eshop) all aggregated properly to ensure consistency in reporting standards.
#    4. How would these data be stored/organized?
#        * Preferably through CSV or any sort of tabular storage format, with each row being a unique game title, with columns and metadata describing the game and sales figures of each region.
# 2. Search for potential **real** datasets that could provide you with something useful for this project.  For each dataset that you find write 3-5 sentences describing
#    1. where the data is located (e.g., URL) and anything you need to do to use it (e.g., ask for permission, fill out an application)
#    2. what the important variables are in this dataset that you might use
#
#    * Dataset 1- Video Game Sales (by anandshaw2001)
#        - This dataset can be found at [this url](https://www.kaggle.com/datasets/anandshaw2001/video-game-sales ). It contains 16,598 game titles covering the period from 1995–2016, and is available to download in csv format for free with zero extra steps. Some key features that we can utilize are “year”, “genre” and regional sales data like “NA_sales”, “JP_sales”, “EU_sales”. Preprocessing may be needed as some data is missing like 278 values from “year”.
#    * Dataset 2: Steam Store Data (Digital/PC Market)
#        - This dataset can be found at [this url](https://www.kaggle.com/datasets/fronkongames/steam-games-dataset) on Kaggle. The data was taken directly from SteamSpy and Steam Store APIs, being free to download with no extra permissions  in csv format (unless we were to take directly from the API, this would require an API key). Some important variables are genre, release data, price, and owners(estimated range of units sold). In order to answer our regional question we may need to use a proxy such as the “supported_languages”.
#    * Dataset 3:  Google Play Store Data
#        - This dataset can be found at [this url](https://www.kaggle.com/datasets/lava18/google-play-store-apps) on Kaggle and can be downloaded for free with no extra permissions in the CSV format. Some important variables are genre, installs (a proxy for sales), price, and content rating. This dataset could prove useful in representing the mobile gaming platform when answering our question.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Since Kaggle is not a simple HTTP download, we directly downloaded the zip file from the site and put them in /data/00-raw

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset #1
#
# **NOTE** The final report should not be overly long.  If this wrangling step is huge and complicated you should remove these sections from the final report and replace them with a statement like "To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis"

# %%
df_videogamesales = pd.read_csv('data/00-raw/videogamesales.csv')
df_videogamesales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# This dataset is quite tidy, as each row contains one observation of a video game, and each column maps one variable. However, there are some missing values in Year and Publisher, as seen above in the non-null count.

# %%
missing = df_videogamesales.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)
missing_pct = (missing / len(df_videogamesales) * 100).round(2)

pd.DataFrame({'missing': missing, 'missing_pct': missing_pct})
# Out:
#            missing  missing_pct
# Year           271         1.63
# Publisher       58         0.35

# %%
df_videogamesales.loc[df_videogamesales['Year'].isna(), df_videogamesales.columns].head()
# Out:
#      Rank                        Name Platform  Year     Genre  \
# 179   180             Madden NFL 2004      PS2   NaN    Sports
# 377   378            FIFA Soccer 2004      PS2   NaN    Sports
# 431   432  LEGO Batman: The Videogame      Wii   NaN    Action
# 470   471  wwe Smackdown vs. Raw 2006      PS2   NaN  Fighting
# 607   608              Space Invaders     2600   NaN   Shooter
#
#                                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 179                         Electronic Arts      4.26      0.26      0.01
# 377                         Electronic Arts      0.59      2.36      0.04
# 431  Warner Bros. Interactive Entertainment      1.86      1.02      0.00
# 470                                     NaN      1.57      1.02      0.00
# 607                                   Atari      2.36      0.14      0.00
#
#      Other_Sales  Global_Sales
# 179         0.71          5.23
# 377         0.51          3.49
# 431         0.29          3.17
# ...

# %%
df_videogamesales.loc[df_videogamesales['Publisher'].isna(), df_videogamesales.columns].head()
# Out:
#       Rank                                               Name Platform  \
# 470    471                         wwe Smackdown vs. Raw 2006      PS2
# 1303  1305                                     Triple Play 99       PS
# 1662  1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222  2224                                 Bentley's Hackpack      GBA
# 3159  3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
#
#         Year     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 470      NaN  Fighting       NaN      1.57      1.02       0.0         0.41
# 1303     NaN    Sports       NaN      0.81      0.55       0.0         0.10
# 1662  2007.0      Misc       NaN      0.87      0.32       0.0         0.02
# 2222  2005.0      Misc       NaN      0.67      0.25       0.0         0.02
# 3159  2004.0      Misc       NaN      0.46      0.17       0.0         0.01
#
#       Global_Sales
# 470           3.00
# 1303          1.46
# 1662          1.21
# ...

# %%
df_videogamesales.isna().any(axis=1).sum()
# Out:
# 307

# %%
year_missing_rate_by_platform = (
    df_videogamesales.assign(year_missing=df_videogamesales['Year'].isna())
      .groupby('Platform')['year_missing']
      .mean()
      .sort_values(ascending=False)
)

pub_missing_rate_by_platform = (
    df_videogamesales.assign(pub_missing=df_videogamesales['Publisher'].isna())
      .groupby('Platform')['pub_missing']
      .mean()
      .sort_values(ascending=False)
)

year_missing_rate_by_genre = (
    df_videogamesales.assign(year_missing=df_videogamesales['Year'].isna())
      .groupby('Genre')['year_missing']
      .mean()
      .sort_values(ascending=False)
)

pub_missing_rate_by_genre = (
    df_videogamesales.assign(pub_missing=df_videogamesales['Publisher'].isna())
      .groupby('Genre')['pub_missing']
      .mean()
      .sort_values(ascending=False)
)

year_missing_rate_by_platform.head(10), pub_missing_rate_by_platform.head(10)
# Out:
# (Platform
#  2600    0.127820
#  Wii     0.026415
#  XB      0.025485
#  GC      0.025180
#  X360    0.023715
#  PS3     0.018811
#  PC      0.017708
#  3DS     0.017682
#  PS2     0.015733
#  DS      0.013870
#  Name: year_missing, dtype: float64,
#  Platform
#  GBA     0.031630
#  PC      0.006250
#  PSV     0.004843
#  3DS     0.003929
#  DS      0.003236
#  X360    0.003162
#  PS      0.002508
#  PS3     0.002257
#  PSP     0.001649
#  PS2     0.000925
#  Name: pub_missing, dtype: float64)

# %%
sales_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
df_videogamesales.groupby(df_videogamesales['Year'].isna())[sales_cols].mean()
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# False  0.265415  0.147554  0.078661     0.048325      0.540232
# True   0.219631  0.092288  0.024797     0.032251      0.369299

# %%
df_videogamesales.groupby(df_videogamesales['Publisher'].isna())[sales_cols].mean()
# Out:
#            NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Publisher
# False      0.265079  0.146883  0.077998     0.048191      0.538426
# True       0.147241  0.080690  0.016034     0.011552      0.256552

# %% [markdown]
# Since the percentage of missing values is so little (307 out of a dataset of 16500+ values; i.e. <%2), and it seems to be randomly distributed, we can simply drop all of those affected rows, as the effects are negligible. To check correlations, we observed the distribution of missing values across platforms, and also across sales columns.

# %%
df_videogamesales.dropna(inplace=True)
df_videogamesales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df_videogamesales['Year'].value_counts()
# Out:
# Year
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: count, dtype: int64

# %%
df_videogamesales['Platform'].value_counts()
# Out:
# Platform
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %%
platforms = ['PS3', 'X360', 'Wii', 'DS', 'PSP', 'PC']
df_videogamesales['Year'] = df_videogamesales['Year'].astype(int)   # as seen above, the year col currently has decimals

df_videogamesales = df_videogamesales.loc[
    df_videogamesales['Year'].between(2006, 2015, inclusive='both')
    & df_videogamesales['Platform'].isin(platforms)
]

df_videogamesales['Year'].value_counts(), df_videogamesales['Platform'].value_counts()
# Out:
# (Year
#  2009    1335
#  2008    1235
#  2010    1219
#  2011     995
#  2007     974
#  2006     608
#  2012     476
#  2013     315
#  2014     233
#  2015     171
#  Name: count, dtype: int64,
#  Platform
#  DS      1988
#  Wii     1290
#  PS3     1272
#  X360    1208
#  PSP     1085
#  PC       718
#  Name: count, dtype: int64)

# %% [markdown]
# To get a sense of what the sales numbers look like, let's make some visualizations.

# %%
plt.figure(figsize=(8,4))
plt.scatter(df_videogamesales['Rank'], df_videogamesales['Global_Sales'], s=8)
plt.title('Global_Sales vs Rank')
plt.xlabel('Rank')
plt.ylabel('Global_Sales (millions)')
plt.tight_layout()
plt.show()

# %% [markdown]
# This makes sense, as the top video games are played much more often than lower ranked ones, so the global sales will be proportionally much higher. There do not seem to be any outliers.

# %%
totals = df_videogamesales[sales_cols].sum()
plt.figure(figsize=(7,4))
plt.bar(totals.index, totals.values)
plt.title('Total sales by region')
plt.xlabel('Region')
plt.ylabel('Total sales (millions)')
plt.tight_layout()
plt.show()

# %% [markdown]
# We will have to keep in mind that our dataset is slightly biased because there is more information from North America than other regions.

# %%
df_videogamesales.to_csv('data/02-processed/videogamesales_clean.csv', index=False)

# %% [markdown]
# ### Dataset #2: Steam Games

# %% [markdown]
# The primary metric that we need to keep track of in this dataset is estimated owners. This is because it is a proxy of how many units of the game have been sold on the PC platform. Exact figures aren't shown (it's not continuous, its categorical ex: 20000-50000). So some interpolation might be needed. There is the Year variable which we converted to be discrete. There is a Genre variable that shows the game genre, it is a list of strings that indicate what type of game it is. There is Supported Languages which could be used as a proxy for the location avaialbility of the Steam game.
#
# Some major concerns about this dataset is that there is a clear lack of precision when it comes to how many sales a game has made. It being ranged based instead of an exact value, we would have to find a midpoint between the range and use it which would cause some margin of error. Furthermore using languages as a proxy for location would introduce some error as well as we have no real way to indicate what percentage of owners of the game came from a certain region. For example if we have 50000 game sales and the support language is JP and EN, we would have no real way of knowing how many of those copies are in English or Japanese. We would need some external way of tracking the traffic of sales of these certain games from each country.

# %%
df_steamgames = pd.read_csv('data/00-raw/steamgames.csv')
df_steamgames.head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# ...

# %%
df_steamgames.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies'],
#       dtype='object')

# %% [markdown]
# Our columns seem to be randomly misnamed: the first few are shifted over to the right one, then Required age and Price are swapped, and the next few seem correct. We will have to manually adjust, as well as narrow down the columns that we are interested in.

# %%
keep = ['AppID', 'Name', 'Release date', 'Supported languages', 'Publishers', 'Genres']
df_steamgames = df_steamgames[keep]
df_steamgames.reset_index(drop=True, inplace=True)
df_steamgames.rename(columns={'AppID': 'Name', 'Name': 'Release date', 'Release date': 'Estimated owners'}, inplace=True)
df_steamgames.head()
# Out:
#                                     Name  Release date Estimated owners  \
# 0             Black Dragon Mage Playtest   Aug 1, 2023            0 - 0
# 1  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016        0 - 20000
# 2      Mystery Solitaire The Black Raven   May 6, 2019        0 - 20000
# 3            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024        0 - 20000
# 4                          Maze Quest VR  Apr 24, 2025        0 - 20000
#
#                           Supported languages            Publishers  \
# 0                                          []                   NaN
# 1                                 ['English']            MangaGamer
# 2  ['English', 'French', 'German', 'Russian']                8floor
# 3                                  ['Korean']                 유진게임즈
# 4                                 ['English']  Reality Expanded LLC
#
#                     Genres
# 0                      NaN
# 1                Adventure
# 2                   Casual
# ...

# %% [markdown]
# The values for `Estimated owners` seem a little strange...

# %%
df_steamgames['Estimated owners'].unique()
# Out:
# array(['0 - 0', '0 - 20000', '100000 - 200000', '500000 - 1000000',
#        '20000 - 50000', '200000 - 500000', '50000 - 100000',
#        '2000000 - 5000000', '10000000 - 20000000', '1000000 - 2000000',
#        '20000000 - 50000000', '5000000 - 10000000',
#        '100000000 - 200000000', '50000000 - 100000000'], dtype=object)

# %% [markdown]
# These columns can help us estimate the popularity of a game, but 0 - 0 is the equivalent of a null value, so we'll drop those rows. Additionally, we can modify Release date to match Year from our first dataset.

# %%
df_steamgames = df_steamgames[df_steamgames['Estimated owners'] != '0 - 0']
df_steamgames['Release date'] = (pd.to_datetime(df_steamgames['Release date'], errors='coerce').dt.year).astype(int)
df_steamgames.rename(columns={'Release date': 'Year'}, inplace=True)

# remember we are only looking at the years 2006-2015
df_steamgames = df_steamgames.loc[df_steamgames['Year'].between(2006, 2015, inclusive='both')]
df_steamgames.head()
# Out:
#                                                   Name  Year  \
# 17                                             Redline  2014
# 34                                          Epic Arena  2015
# 69                               New kind of adventure  2015
# 100  March of Industry: Very Capitalist Factory Sim...  2015
# 103                        My Lands: Black Gem Hunting  2014
#
#      Estimated owners                                Supported languages  \
# 17          0 - 20000                                        ['English']
# 34    100000 - 200000  ['English', 'German', 'Russian', 'Ukrainian', ...
# 69   500000 - 1000000                                        ['English']
# 100         0 - 20000  ['English', 'French', 'Italian', 'German', 'Sp...
# 103  500000 - 1000000  ['English', 'French', 'Italian', 'German', 'Sp...
#
#                           Publishers  \
# 17           Atari,Nightdive Studios
# 34                    Shadow Masters
# 69             Back To Basics Gaming
# ...

# %%
df_steamgames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5925 entries, 17 to 122558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 5925 non-null   object
#  1   Year                 5925 non-null   int64
#  2   Estimated owners     5925 non-null   object
#  3   Supported languages  5925 non-null   object
#  4   Publishers           5773 non-null   object
#  5   Genres               5909 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 324.0+ KB

# %%
df_steamgames.isna().any(axis=1).sum()
# Out:
# 167

# %%
df_steamgames.loc[df_steamgames['Publishers'].isna(), df_steamgames.columns].head()
# Out:
#                                     Name  Year Estimated owners  \
# 1091        The Otherside: Realm of Eons  2010        0 - 20000
# 1219                       A Pixel Story  2015        0 - 20000
# 1526                      Planet Busters  2008        0 - 20000
# 4166                     Rubber and Lead  2015    20000 - 50000
# 4914  Mystery P.I. - Lost in Los Angeles  2009    20000 - 50000
#
#      Supported languages Publishers                  Genres
# 1091         ['English']        NaN                  Casual
# 1219         ['English']        NaN  Action,Adventure,Indie
# 1526         ['English']        NaN            Indie,Casual
# 4166         ['English']        NaN        Action,Indie,RPG
# 4914         ['English']        NaN                  Casual

# %%
df_steamgames.loc[df_steamgames['Genres'].isna(), df_steamgames.columns].head()
# Out:
#                                                     Name  Year  \
# 3280                                           Air Forte  2010
# 15650        Hotline Miami 2: Wrong Number Digital Comic  2015
# 23311                          CRYENGINE - Sample Assets  2014
# 27567        Call of Cthulhu®: Dark Corners of the Earth  2009
# 29732  The Elder Scrolls IV: Oblivion® Game of the Ye...  2009
#
#         Estimated owners Supported languages          Publishers Genres
# 3280       20000 - 50000         ['English']        Blendo Games    NaN
# 15650     50000 - 100000         ['English']    Devolver Digital    NaN
# 23311          0 - 20000         ['English']              Crytek    NaN
# 27567    200000 - 500000         ['English']  Bethesda Softworks    NaN
# 29732  2000000 - 5000000         ['English']  Bethesda Softworks    NaN

# %%
pub_missing_rate_by_genre = (
    df_steamgames.assign(pub_missing=df_steamgames['Publishers'].isna())
      .groupby('Genres')['pub_missing']
      .mean()
      .sort_values(ascending=False)
)

pub_missing_rate_by_genre.head(10)
# Out:
# Genres
# Action,Adventure,Casual,Indie,RPG,Strategy,Early Access             1.0
# Early Access,Indie                                                  1.0
# RPG,Indie,Casual                                                    1.0
# Strategy,Action,Indie                                               1.0
# Casual,Strategy,Indie                                               1.0
# Casual,Indie,Massively Multiplayer,Strategy                         1.0
# Adventure,RPG,Strategy,Early Access                                 1.0
# Action,Adventure,Free To Play,Sports,Strategy                       1.0
# Strategy,Simulation                                                 1.0
# Free To Play,Indie,Massively Multiplayer,RPG,Simulation,Strategy    1.0
# Name: pub_missing, dtype: float64

# %% [markdown]
# To deal with null values, we know the most important values are the year, region, and genres of each video game. It appears that we have 167/5925 rows containing any missing values, which is only 2.8%. After a quick correlation check to see that there is no apparent skew, it would be reasonable to simply drop all of those rows.

# %%
df_steamgames.dropna(inplace=True)
df_steamgames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5758 entries, 17 to 122558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 5758 non-null   object
#  1   Year                 5758 non-null   int64
#  2   Estimated owners     5758 non-null   object
#  3   Supported languages  5758 non-null   object
#  4   Publishers           5758 non-null   object
#  5   Genres               5758 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 314.9+ KB

# %%
df_steamgames.head()
# Out:
#                                                   Name  Year  \
# 17                                             Redline  2014
# 34                                          Epic Arena  2015
# 69                               New kind of adventure  2015
# 100  March of Industry: Very Capitalist Factory Sim...  2015
# 103                        My Lands: Black Gem Hunting  2014
#
#      Estimated owners                                Supported languages  \
# 17          0 - 20000                                        ['English']
# 34    100000 - 200000  ['English', 'German', 'Russian', 'Ukrainian', ...
# 69   500000 - 1000000                                        ['English']
# 100         0 - 20000  ['English', 'French', 'Italian', 'German', 'Sp...
# 103  500000 - 1000000  ['English', 'French', 'Italian', 'German', 'Sp...
#
#                           Publishers  \
# 17           Atari,Nightdive Studios
# 34                    Shadow Masters
# 69             Back To Basics Gaming
# ...

# %%
df_steamgames.to_csv('data/02-processed/steamgames_clean.csv', index=False)

# %% [markdown]
# ### Dataset #3: Google Play Store
#
# The key metric in this is Installs, which indicates if the game was sold or not. It is presented as a milestone range and is discrete (e.g., "1,000,000+"). We also have the Category varaible that allows us to filter apps that are only games. This allows us to have some inclusion of moible games. There is also Genre, which is categorical and is a list of strings that could indicate what the game is about.
#
# One major concern about this data is that there is a lack of time series. We don't know when the game was released so we aren't ab le to isolate a time period to answer our research question. Additionally there is no metrics on region which we need to answer our research question. This data set might not be usuable in it's current state, unless we were to aggregate it with another dataset that includes the above information (as it is crucial).

# %%
df_googleplaystore = pd.read_csv('data/00-raw/googleplaystore.csv')
df_googleplaystore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_googleplaystore['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# Since we are researching video games, we can look exclusively at the apps under the game category.

# %%
df_googleplaystore = df_googleplaystore[df_googleplaystore['Category'] == 'GAME']
df_googleplaystore.head()
# Out:
#                    App Category  Rating   Reviews Size        Installs  Type  \
# 1653            ROBLOX     GAME     4.5   4447388  67M    100,000,000+  Free
# 1654    Subway Surfers     GAME     4.5  27722264  76M  1,000,000,000+  Free
# 1655  Candy Crush Saga     GAME     4.4  22426677  74M    500,000,000+  Free
# 1656         Solitaire     GAME     4.7    254258  23M     10,000,000+  Free
# 1657    Bubble Shooter     GAME     4.5    148897  46M     10,000,000+  Free
#
#      Price Content Rating                        Genres    Last Updated  \
# 1653     0   Everyone 10+  Adventure;Action & Adventure   July 31, 2018
# 1654     0   Everyone 10+                        Arcade   July 12, 2018
# 1655     0       Everyone                        Casual    July 5, 2018
# 1656     0       Everyone                          Card  August 1, 2018
# 1657     0       Everyone                        Casual   July 17, 2018
#
#        Current Ver   Android Ver
# 1653  2.347.225742    4.1 and up
# ...

# %%
keep = ['App', 'Installs', 'Genres']
df_googleplaystore = df_googleplaystore[keep]
df_googleplaystore.head()
# Out:
#                    App        Installs                        Genres
# 1653            ROBLOX    100,000,000+  Adventure;Action & Adventure
# 1654    Subway Surfers  1,000,000,000+                        Arcade
# 1655  Candy Crush Saga    500,000,000+                        Casual
# 1656         Solitaire     10,000,000+                          Card
# 1657    Bubble Shooter     10,000,000+                        Casual

# %%
df_googleplaystore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1144 entries, 1653 to 10804
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   App       1144 non-null   object
#  1   Installs  1144 non-null   object
#  2   Genres    1144 non-null   object
# dtypes: object(3)
# memory usage: 35.8+ KB

# %% [markdown]
# There are no null values, but there is also no year or regional indicators, so this dataset may not be very helpful for us.

# %%
df_googleplaystore.to_csv('data/02-processed/googleplaystore_clean.csv', index=False)

# %% [markdown]
# ### Combining Data
#
# Combining Data
# We are leaning towards sticking with only the first dataset (video game sales) for all the reasons discussed above, but we may potentially add in the second dataset (steam games) by checking for identical titles and matching the years. From the second dataset, we can use supported languages as the proxy for determining region, though not entirely reliable. Further cleaning can be done on the genres to ensure a standard set of terms. However, we shall proceed with only the first dataset for now.

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('data/02-processed/videogamesales_clean.csv')

# Mapping 12 genres into 4 broader categories
genre_mapping = {
    'Action': 'Action/Competitive', 'Shooter': 'Action/Competitive',
    'Fighting': 'Action/Competitive', 'Racing': 'Action/Competitive',
    'Sports': 'Action/Competitive', 'Role-Playing': 'Narrative',
    'Adventure': 'Narrative', 'Strategy': 'Strategy/Cognitive',
    'Simulation': 'Strategy/Cognitive', 'Puzzle': 'Strategy/Cognitive',
    'Misc': 'Misc', 'Platform': 'Misc'
}
df['Genre_Category'] = df['Genre'].map(genre_mapping)

# Filter the 2006-2015, 6 platforms
platforms = ['PS3', 'X360', 'Wii', 'DS', 'PSP', 'PC']
df_filtered = df[
    (df['Year'].between(2006, 2015, inclusive='both')) &
    (df['Platform'].isin(platforms))
].copy()

# Genre ordering for consistent visualization
genre_order = ['Action/Competitive', 'Narrative', 'Strategy/Cognitive', 'Misc']
region_order = ['NA', 'EU', 'JP']

# Showing first few rows of filtered data
df_filtered[['Name', 'Platform', 'Year', 'Genre', 'Genre_Category', 'NA_Sales', 'EU_Sales', 'JP_Sales']].head(10)
# Out:
#                         Name Platform  Year     Genre      Genre_Category  \
# 0                 Wii Sports      Wii  2006    Sports  Action/Competitive
# 1             Mario Kart Wii      Wii  2008    Racing  Action/Competitive
# 2          Wii Sports Resort      Wii  2009    Sports  Action/Competitive
# 3      New Super Mario Bros.       DS  2006  Platform                Misc
# 4                   Wii Play      Wii  2006      Misc                Misc
# 5  New Super Mario Bros. Wii      Wii  2009  Platform                Misc
# 6                    Wii Fit      Wii  2007    Sports  Action/Competitive
# 7               Wii Fit Plus      Wii  2009    Sports  Action/Competitive
# 8         Kinect Adventures!     X360  2010      Misc                Misc
# 9         Grand Theft Auto V      PS3  2013    Action  Action/Competitive
#
#    NA_Sales  EU_Sales  JP_Sales
# 0     41.49     29.02      3.77
# 1     15.85     12.88      3.79
# 2     15.75     11.01      3.28
# ...

# %% [markdown]
# ## Section 1: Regional Market Sizes (2006-2015)
#
# We first establish the relative market sizes across North America, Europe, and Japan to investigate genre preference across different regions.

# %%
regional_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales']
market_share_table = pd.DataFrame({
    'total_sales_millions': df_filtered[regional_cols].sum(),
    'market_share_pct': (df_filtered[regional_cols].sum() / df_filtered[regional_cols].sum().sum() * 100)
}).round(2)
market_share_table
# Out:
#           total_sales_millions  market_share_pct
# NA_Sales               1927.07             55.41
# EU_Sales               1180.43             33.94
# JP_Sales                370.50             10.65

# %% [markdown]
# Now we make visualization to observe market share changes across different regions and time.

# %%
yearly_totals = df_filtered.groupby('Year')[regional_cols].sum()
yearly_totals.plot(kind='line', figsize=(10, 6))
plt.title('Total Regional Sales Over Time (2006–2015)', fontweight='bold', fontsize=12)
plt.xlabel('Year')
plt.ylabel('Total Sales (millions)')
plt.legend(title='Region', frameon=False)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Additionally lets take a look**

# %% [markdown]
# The temporal plot shows that total sales in all three regions peak around 2008–2009 and decline thereafter, consistent with the late lifecycle of the seventh console generation. While the overall market contracts after this period, the relative ranking of regions remains consistent throughout the decade.
#
# Across 2006–2015, North America accounts for the largest share of total sales (55.4%), followed by Europe (33.9%) and Japan (10.7%). Although absolute sales decline in all regions after 2009, their proportional contributions to total sales remain broadly stable over time.
#
# Because the regions differ substantially in market size, we analyze genre preferences using market share, defined as the proportion of total regional sales attributable to each genre in a given year. This normalization removes scale effects and allows meaningful comparison of demand composition across regions, which directly supports our research question regarding regional genre preference patterns.

# %% [markdown]
# ## Regional Genre Preferences: Year-by_year Market Share (2006 - 2015)
#
# We examine how genre market share evolved annually within each region. By calculating market share per year, we can observe temporal shifts in preferences rather than relying on aggregate summaries that may ignore important trends.

# %%
platforms = ['PS3', 'X360', 'Wii', 'DS', 'PSP', 'PC']
df_pref = df[(df['Year'].between(2006, 2015)) & (df['Platform'].isin(platforms))].copy()

# Calculate market share by year, region, and genre
pref_long = df_pref.melt(
    id_vars=['Year', 'Genre_Category'],
    value_vars=['NA_Sales', 'EU_Sales', 'JP_Sales'],
    var_name='Region',
    value_name='Sales_Millions'
)
pref_long['Region'] = pref_long['Region'].str.replace('_Sales', '', regex=False)

# Aggregate by Year, Region, Genre
yearly_genre = (
    pref_long.groupby(['Year', 'Region', 'Genre_Category'], as_index=False)['Sales_Millions']
    .sum()
)

# Calculate market share within each year-region
yearly_genre['Market_Share_Pct'] = (
    yearly_genre.groupby(['Year', 'Region'])['Sales_Millions']
    .transform(lambda x: x / x.sum() * 100)
)

# %% [markdown]
# We now show NA, EU, and JP sales by year and genre category in separate tables below:

# %%
region_data = yearly_genre[yearly_genre['Region'] == 'NA']
pivot_table_na = region_data.pivot(
    index='Year', 
    columns='Genre_Category', 
    values='Market_Share_Pct'
)[genre_order].round(1)

print("Pivot Table for NA Region:")
pivot_table_na
# Out:
# Pivot Table for NA Region:
# Genre_Category  Action/Competitive  Narrative  Strategy/Cognitive  Misc
# Year
# 2006                          59.4       12.0                 7.6  21.0
# 2007                          53.7       11.1                14.1  21.2
# 2008                          59.1       11.1                11.7  18.1
# 2009                          63.3        8.8                 9.9  18.0
# 2010                          56.8       11.5                 7.8  23.8
# 2011                          66.8       11.4                 3.8  18.0
# 2012                          80.2       11.7                 1.5   6.6
# 2013                          78.7        5.4                 2.3  13.6
# 2014                          75.1       12.5                 2.9   9.5
# 2015                          75.8       11.9                 4.5   7.8

# %%
region_data = yearly_genre[yearly_genre['Region'] == 'EU']
pivot_table_eu = region_data.pivot(
    index='Year', 
    columns='Genre_Category', 
    values='Market_Share_Pct'
)[genre_order].round(1)

print("Pivot Table for EU Region:")
pivot_table_eu
# Out:
# Pivot Table for EU Region:
# Genre_Category  Action/Competitive  Narrative  Strategy/Cognitive  Misc
# Year
# 2006                          58.3        8.5                 8.5  24.7
# 2007                          57.6        8.2                16.0  18.2
# 2008                          62.5        9.3                11.5  16.6
# 2009                          64.8        7.3                11.4  16.5
# 2010                          60.6       10.8                 8.3  20.3
# 2011                          70.9       12.3                 4.4  12.4
# 2012                          81.1       11.1                 2.5   5.3
# 2013                          81.1        4.8                 3.7  10.4
# 2014                          71.4       10.9                 7.9   9.8
# 2015                          71.8       12.2                10.4   5.7

# %%
region_data = yearly_genre[yearly_genre['Region'] == 'JP']
pivot_table_jp = region_data.pivot(
    index='Year', 
    columns='Genre_Category', 
    values='Market_Share_Pct'
)[genre_order].round(1)

print("Pivot Table for JP Region:")
pivot_table_jp
# Out:
# Pivot Table for JP Region:
# Genre_Category  Action/Competitive  Narrative  Strategy/Cognitive  Misc
# Year
# 2006                          21.1       25.0                10.4  43.6
# 2007                          31.5       27.0                14.2  27.3
# 2008                          35.9       36.6                10.5  17.0
# 2009                          42.6       33.3                 6.6  17.5
# 2010                          29.5       45.8                 7.1  17.6
# 2011                          41.5       38.2                 5.3  15.0
# 2012                          51.4       34.8                 8.5   5.3
# 2013                          62.8       30.7                 3.2   3.3
# 2014                          69.8       24.3                 1.8   4.1
# 2015                          79.9       19.5                 0.0   0.5

# %% [markdown]
# Now we make visualization of the genre market share within each region by year.

# %%
# Visualize for all regions together
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

for i, region in enumerate(region_order):
    ax = axes[i]
    region_data = yearly_genre[yearly_genre['Region'] == region]
    
    # Pivot for stacked area plot
    pivot = region_data.pivot(index='Year', columns='Genre_Category', values='Market_Share_Pct')[genre_order]
    
    # Stacked area chart
    ax.stackplot(
        pivot.index, 
        pivot['Action/Competitive'],
        pivot['Narrative'],
        pivot['Strategy/Cognitive'],
        pivot['Misc'],
        labels=genre_order,
        alpha=0.8
    )
    
    ax.set_title(f'{region}', fontweight='bold', fontsize=11)
    ax.set_xlabel('Year')
    if i == 0:
        ax.set_ylabel('Market Share (%)')
    ax.set_ylim(0, 100)
    ax.grid(True, alpha=0.2, axis='y')
    ax.legend(loc='upper left', fontsize=8, frameon=False)

plt.tight_layout()
plt.suptitle('Genre Market Share Composition by Region (2006–2015)', y=1.02, fontweight='bold', fontsize=12)
plt.show()

# %% [markdown]
# Additionally to **explicitly test our hypothesis regarding whether the "gap" between regions has changed over time**, we can plot the market share of the dominant genres across the three regions on the same axes. This directly visualizes convergence or divergence.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Action/Competitive spread across regions
for region in region_order:
    region_data = yearly_genre[(yearly_genre['Region'] == region) & (yearly_genre['Genre_Category'] == 'Action/Competitive')]
    axes[0].plot(region_data['Year'], region_data['Market_Share_Pct'], label=region, linewidth=2.5, marker='o')

axes[0].set_title('Action/Competitive Market Share Gap over Time')
axes[0].set_ylabel('Market Share (%)')
axes[0].set_xlabel('Year')
axes[0].legend()
axes[0].grid(alpha=0.3)
axes[0].set_ylim(0, 100)

# Plot 2: Narrative spread across regions
for region in region_order:
    region_data = yearly_genre[(yearly_genre['Region'] == region) & (yearly_genre['Genre_Category'] == 'Narrative')]
    axes[1].plot(region_data['Year'], region_data['Market_Share_Pct'], label=region, linewidth=2.5, marker='o')

axes[1].set_title('Narrative Market Share Gap over Time')
axes[1].set_ylabel('Market Share (%)')
axes[1].set_xlabel('Year')
axes[1].legend()
axes[1].grid(alpha=0.3)
axes[1].set_ylim(0, 100)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation of Temporal Genre Market Share Patterns**
#
# The stacked area charts reveal distinct regional differences in genre preferences:
#
# **North America and Europe:** Both regions show remarkably similar patterns, with Action/Competitive titles consistently dominating at 55–70% of market share throughout 2006–2015. Narrative titles maintain a stable 10–15% share, while Strategy/Cognitive and Misc genres occupy smaller portions. The near-identical composition suggests convergent preferences between these Western markets.
#
# **Japan:** Japanese preferences diverge notably from Western regions. While Action/Competitive titles grow from 20–40% in early years to 45–75% by 2015, Narrative titles command a substantially higher share (25–50%) compared to NA and EU. This reflects a clear regional preference for story-driven and role-playing games that persists throughout the decade.
#
# **Key Finding:** Regional genre preferences remain stable and differentiated across the entire period. Japan consistently allocates more sales to Narrative content, while NA and EU strongly favor Action/Competitive games, indicating that regional differences reflect enduring cultural factors rather than temporary market trends.

# %% [markdown]
# ## Section 2: Platform-Level Analysis: Genre Market Share by Region Across All Six Platforms
#
# We examine regional genre preferences **within each platform** to determine whether regional differences persist when accounting for platform.
#
# 1. **Compute market share** within each (Year, Platform, Region) combination
# 2. **Compute the mean of yearly market shares (2006–2015)** for each (Platform, Region, Genre). These values represent the unweighted average of annual market shares rather than sales-weighted totals across the entire period. This approach ensures equal temporal weighting, preventing the high-sales peak years (2008–2009) from dominating the analysis, and accounts for the fact that different platforms peaked at different times.
#
# This symmetric approach treats all six platforms equally and allows direct comparison of regional genre composition within each hardware ecosystem. By conditioning on platform, we evaluate whether regional differences remain even when platform adoption patterns are held constant.

# %%
pref_platform = df_pref.melt(
    id_vars=['Year', 'Platform', 'Genre_Category'],
    value_vars=['NA_Sales', 'EU_Sales', 'JP_Sales'],
    var_name='Region',
    value_name='Sales_Millions'
)
pref_platform['Region'] = pref_platform['Region'].str.replace('_Sales', '', regex=False)

platform_genre = (
    pref_platform.groupby(['Year', 'Region', 'Platform', 'Genre_Category'], as_index=False)['Sales_Millions']
    .sum()
)

platform_genre['Market_Share_Pct'] = (
    platform_genre.groupby(['Year', 'Region', 'Platform'])['Sales_Millions']
    .transform(lambda x: x / x.sum() * 100 if x.sum() > 0 else 0)
)

avg_platform_genre = (
    platform_genre.groupby(['Platform', 'Region', 'Genre_Category'], as_index=False)['Market_Share_Pct']
    .mean()
)

# %%
for platform in platforms:
    platform_data = avg_platform_genre[avg_platform_genre['Platform'] == platform].copy()
    pivot = platform_data.pivot(
        index='Region',
        columns='Genre_Category',
        values='Market_Share_Pct'
    )[genre_order].round(1)
    print(f"\n{platform}:")
    display(pivot)
# Out:
# PS3:
# Genre_Category  Action/Competitive  Narrative  Strategy/Cognitive  Misc
# Region
# EU                            83.3        7.4                 1.7   7.6
# JP                            71.6       21.1                 4.5   2.8
# NA                            80.3        9.6                 1.9   8.3
# X360:
# Genre_Category  Action/Competitive  Narrative  Strategy/Cognitive  Misc
# Region
# EU                            80.8        9.1                 2.7   7.3
# JP                            59.4       22.0                 5.8   2.8
# NA                            78.9        9.3                 2.5   9.3
# Wii:
# Genre_Category  Action/Competitive  Narrative  Strategy/Cognitive  Misc
# Region
# EU                            49.9        3.0                 3.9  44.6
# JP                            28.2       10.9                 7.8  36.9
# NA                            45.4        2.8                 5.5  47.9
# DS:
# ...

# %% [markdown]
# Now we use faceted bar chart to visualize all platforms simultaneously.
#
# **For easier viewing provided is a heatmap to see dominant genres.

# %%
import seaborn as sns

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for idx, platform in enumerate(platforms):
    ax = axes[idx]
    platform_data = avg_platform_genre[avg_platform_genre['Platform'] == platform]
    
    if len(platform_data) > 0:
        pivot = platform_data.pivot(index='Region', columns='Genre_Category', values='Market_Share_Pct')
        pivot = pivot.reindex(index=region_order, columns=genre_order, fill_value=0)
        
        sns.heatmap(pivot, annot=True, fmt=".1f", cmap="YlGnBu", ax=ax, cbar=(idx%3==2), vmin=0, vmax=100)
        
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.set_title(platform, fontweight='bold', fontsize=12)
    else:
        ax.text(0.5, 0.5, f'No data for {platform}', 
                ha='center', va='center', transform=ax.transAxes)
        ax.set_xticks([])
        ax.set_yticks([])

plt.tight_layout()
plt.suptitle('Average Genre Market Share by Platform and Region (Heatmap)', 
             y=1.03, fontweight='bold', fontsize=14)
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

genre_colors = {
    'Action/Competitive': '#e74c3c',
    'Narrative': '#3498db',
    'Strategy/Cognitive': '#2ecc71',
    'Misc': '#f39c12'
}

for idx, platform in enumerate(platforms):
    ax = axes[idx]
    platform_data = avg_platform_genre[avg_platform_genre['Platform'] == platform]
    
    if len(platform_data) > 0:
        pivot = platform_data.pivot(index='Region', columns='Genre_Category', values='Market_Share_Pct')
        pivot = pivot.reindex(index=region_order, columns=genre_order, fill_value=0)
        
        x = np.arange(len(region_order))
        width = 0.2
        
        for i, genre in enumerate(genre_order):
            ax.bar(x + i*width, pivot[genre].values, width, 
                   label=genre, color=genre_colors[genre], alpha=0.85)
        
        ax.set_xlabel('Region', fontweight='bold')
        ax.set_ylabel('Market Share (%)', fontweight='bold')
        ax.set_title(platform, fontweight='bold', fontsize=12)
        ax.set_xticks(x + width * 1.5)
        ax.set_xticklabels(region_order)
        ax.set_ylim(0, 100)
        ax.grid(True, alpha=0.3, axis='y')
        
        if idx == 0:
            ax.legend(loc='upper right', fontsize=9, frameon=False)
    else:
        ax.text(0.5, 0.5, f'No data for {platform}', 
                ha='center', va='center', transform=ax.transAxes)
        ax.set_xticks([])
        ax.set_yticks([])

plt.tight_layout()
plt.suptitle('Average Genre Market Share by Platform and Region (2006–2015)', 
             y=1.00, fontweight='bold', fontsize=14)
plt.show()

# %% [markdown]
# ## Key Platform-Level Findings
#
#
# **Console platforms (PS3, X360):**
# Action/Competitive titles dominate in NA and EU (approximately 75–85% of market share). Japan, while still Action-heavy, maintains a substantially higher Narrative share than Western regions.
#
# **Nintendo platforms (Wii, DS):**
# Genre distributions are more diversified. Japan shows particularly strong Narrative representation on DS, whereas NA and EU display more balanced mixes across Action and Misc categories.
#
# **PSP:**
# Japan exhibits notably higher Narrative share relative to NA and EU, suggesting stronger regional differentiation on handheld-oriented platforms.
#
# **PC:**
# Reported Japanese sales for PC are minimal in this dataset, limiting interpretability. NA and EU show relatively higher Strategy/Cognitive shares compared to console platforms.
#
# **PC Platform – Data Limitation**
#
# The dataset contains minimal to no reported PC sales for Japan during 2006–2015. As a result, Japanese genre shares on PC appear as zeros in the visualization. This likely reflects data sparsity or reporting limitations rather than the absence of a PC gaming market in Japan.
#
# Therefore, excluding PC platform is reasonable for final analysis.

# %% [markdown]
# ### Analysis of All Three Data Sets

# %% [markdown]
# #### Imports and Configurations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from scipy import stats
from scipy.stats import chi2_contingency, kruskal, mannwhitneyu
from itertools import combinations
import warnings
warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.dpi': 120,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.titlesize': 13,
    'axes.labelsize': 11,
    'font.family': 'sans-serif'
})

REGION_COLORS = {'NA': '#2196F3', 'EU': '#4CAF50', 'JP': '#FF5722'}
GENRE_COLORS  = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']  
GENRES        = ['Action/Competitive', 'Narrative', 'Strategy/Cognitive', 'Misc']

GENRE_MAP = {
    'Action':       'Action/Competitive',
    'Shooter':      'Action/Competitive',
    'Fighting':     'Action/Competitive',
    'Racing':       'Action/Competitive',
    'Sports':       'Action/Competitive',
    'Role-Playing': 'Narrative',
    'Adventure':    'Narrative',
    'Strategy':     'Strategy/Cognitive',
    'Simulation':   'Strategy/Cognitive',
    'Puzzle':       'Strategy/Cognitive',
    'Misc':         'Misc',
    'Platform':     'Misc'
}

# %% [markdown]
# ### 1 Video Game Sales Analysis
#
# This dataset directly answers the research question. The EDA established that:
# - NA accounts for ~55.4% of total regional sales, EU ~33%, and JP ~ 10.7%
# - All regions peak around 2008-2009 and decline thereafter
# - Stacked area charts show Japan has a visibly higher Narrative share; NA and EU skew heavily Action/Competitive
# - Platform-level heatmaps confirm region differences persist within each of the 6 platforms selected
#
# This section now formally tests whether those visual differences are statistically significant.

# %% [markdown]
# #### 1.1 Load Processed Data & Compute Market Shares

# %%
df_vg = pd.read_csv('data/02-processed/videogamesales_clean.csv')

PLATFORMS = ['PS3', 'X360', 'Wii', 'DS', 'PSP', 'PC']
df_vg = df_vg[
    df_vg['Platform'].isin(PLATFORMS) &
    df_vg['Year'].between(2006, 2015)
].copy()
df_vg['Genre_Cat'] = df_vg['Genre'].map(GENRE_MAP)

print(f'Loaded: {df_vg.shape[0]:,} rows | Platforms: {sorted(df_vg["Platform"].unique())} | Years: {df_vg["Year"].min()}–{df_vg["Year"].max()}')
print(df_vg['Genre_Cat'].value_counts())
# Out:
# Loaded: 7,561 rows | Platforms: ['DS', 'PC', 'PS3', 'PSP', 'Wii', 'X360'] | Years: 2006–2015
# Genre_Cat
# Action/Competitive    3806
# Narrative             1364
# Misc                  1216
# Strategy/Cognitive    1175
# Name: count, dtype: int64

# %%
# Aggregate sales by Platform x Year x Genre_Cat
agg_vg = df_vg.groupby(['Platform', 'Year', 'Genre_Cat'], as_index=False).agg(
    NA_Sales=('NA_Sales', 'sum'),
    EU_Sales=('EU_Sales', 'sum'),
    JP_Sales=('JP_Sales', 'sum')
)

# Genre market share = genre-specific regional sales / total regional sales for that Platform-Year
totals = agg_vg.groupby(['Platform', 'Year'])[['NA_Sales','EU_Sales','JP_Sales']].transform('sum')
agg_vg['NA_Share'] = agg_vg['NA_Sales'] / totals['NA_Sales']
agg_vg['EU_Share'] = agg_vg['EU_Sales'] / totals['EU_Sales']
agg_vg['JP_Share'] = agg_vg['JP_Sales'] / totals['JP_Sales']

regions = {'NA': 'NA_Share', 'EU': 'EU_Share', 'JP': 'JP_Share'}

print('Market share table sample (first 12 rows):')
agg_vg.head(12)
# Out:
# Market share table sample (first 12 rows):
#    Platform  Year           Genre_Cat  NA_Sales  EU_Sales  JP_Sales  NA_Share  \
# 0        DS  2006  Action/Competitive     11.34      1.30      3.38  0.223978
# 1        DS  2006                Misc     18.35     13.34     19.49  0.362433
# 2        DS  2006           Narrative     12.41      5.73     11.72  0.245112
# 3        DS  2006  Strategy/Cognitive      8.53      3.16      3.97  0.168477
# 4        DS  2007  Action/Competitive     23.36      7.73      3.60  0.305919
# 5        DS  2007                Misc     18.22      6.06      9.24  0.238607
# 6        DS  2007           Narrative     10.09      2.45      7.97  0.132137
# 7        DS  2007  Strategy/Cognitive     24.69     18.34      6.00  0.323337
# 8        DS  2008  Action/Competitive     20.24      8.19      2.90  0.254912
# 9        DS  2008                Misc     17.70      8.22      6.87  0.222922
# ...

# %% [markdown]
# #### 1.2 Chi-Square Test - Do Genre Distributions Differ Across Regions?
#
# We build a contingency table of total sales per region x genre category and test whether the genre distribution is independent of region.
#
# - H0: The distribution of sales across genre categories is the same in NA, EU, and JP
# - H1: At least one region has a significantly different genre distribution

# %%
contingency = df_vg.groupby('Genre_Cat')[['NA_Sales','EU_Sales','JP_Sales']].sum()
contingency.columns = ['NA', 'EU', 'JP']
contingency = contingency.reindex(GENRES)

print('Contingency table (total sales in millions):')
print(contingency.round(2))
print()

chi2_vg, p_vg, dof_vg, expected_vg = chi2_contingency(contingency)
n_vg = contingency.values.sum()
cramers_v_vg = np.sqrt(chi2_vg / (n_vg * (min(contingency.shape) - 1)))
effect_vg = 'negligible' if cramers_v_vg < 0.1 else 'small' if cramers_v_vg < 0.3 else 'medium' if cramers_v_vg < 0.5 else 'large'

print(f'Chi-Square Statistic : {chi2_vg:.4f}')
print(f'Degrees of Freedom   : {dof_vg}')
print(f'p-value              : {p_vg:.2e}')
print(f"Cramer's V           : {cramers_v_vg:.4f}  ({effect_vg} effect size)")
print()
print('Reject H0 - genre distributions differ significantly across regions (p < 0.05).' if p_vg < 0.05
      else 'Fail to reject H0 - no significant difference detected.')
# Out:
# Contingency table (total sales in millions):
#                          NA      EU      JP
# Genre_Cat
# Action/Competitive  1202.96  778.74  137.48
# Narrative            205.37  109.86  125.71
# Strategy/Cognitive   162.52  106.18   31.65
# Misc                 356.22  185.65   75.66
#
# Chi-Square Statistic : 193.9831
# Degrees of Freedom   : 6
# p-value              : 3.62e-39
# Cramer's V           : 0.1670  (small effect size)
#
# Reject H0 - genre distributions differ significantly across regions (p < 0.05).

# %%
fig, ax = plt.subplots(figsize=(10, 5))
x = np.arange(len(GENRES))
w = 0.25
for i, (region, color) in enumerate(REGION_COLORS.items()):
    ax.bar(x + i*w, contingency[region].values, width=w, label=region, color=color, edgecolor='white')
ax.set_xticks(x + w)
ax.set_xticklabels(GENRES, fontsize=10)
ax.set_ylabel('Total Sales (millions)')
ax.set_title(
    f'Total Sales by Genre Category and Region (2006-2015)\n'
    f'Chi2 = {chi2_vg:.2f},  p = {p_vg:.2e},  Cramers V = {cramers_v_vg:.3f} ({effect_vg} effect)'
)
ax.legend(title='Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.3 Kruskal-Wallis Test + Mann-Whitney Post-Hoc
#
# The Chi-Square test uses total sales aggregates. Here, we use the distribution of per-(Platform, Year) market-share values to test whether regional differences hold at finer granularity.
#
# - Kruskal-Wallis tests whether at least one region differs per genre (non-parametric, no normality assumption)
# - Mann-Whitney U pairwise post-hoc tests identity which region pairs drive the difference, with Bonferroni correction for multiple comparisons

# %%
print('Kruskal-Wallis H-Test: Regional Genre Market Share Distributions')
print('=' * 65)
kruskal_results = {}
for genre in GENRES:
    sub = agg_vg[agg_vg['Genre_Cat'] == genre]
    na = sub['NA_Share'].dropna()
    eu = sub['EU_Share'].dropna()
    jp = sub['JP_Share'].dropna()
    h, p = kruskal(na, eu, jp)
    kruskal_results[genre] = {'H': h, 'p': p}
    sig = 'Significant' if p < 0.05 else 'Not significant'
    print(f'{genre:<25}  H = {h:7.3f}  p = {p:.4f}  -> {sig}')

print()
print('p < 0.05 means at least one region differs significantly in that genre market share.')
# Out:
# Kruskal-Wallis H-Test: Regional Genre Market Share Distributions
# ...
# Action/Competitive         H =   6.832  p = 0.0328  -> Significant
# Narrative                  H =  31.642  p = 0.0000  -> Significant
# Strategy/Cognitive         H =   0.055  p = 0.9730  -> Not significant
# Misc                       H =   0.844  p = 0.6556  -> Not significant
#
# p < 0.05 means at least one region differs significantly in that genre market share.

# %%
region_pairs = list(combinations(regions.items(), 2))
adj_alpha = 0.05 / (len(GENRES) * len(region_pairs))

print(f'Mann-Whitney U Post-Hoc Tests (Bonferroni-corrected alpha = {adj_alpha:.4f})')
print('=' * 72)

for genre in GENRES:
    sub = agg_vg[agg_vg['Genre_Cat'] == genre]
    print(f' {genre}')
    for (r1name, r1col), (r2name, r2col) in region_pairs:
        u, p = mannwhitneyu(sub[r1col].dropna(), sub[r2col].dropna(), alternative='two-sided')
        sig = '[SIG]' if p < adj_alpha else '      '
        print(f'     {r1name} vs {r2name}  U = {u:6.0f}  p = {p:.4f}   {sig}')
    print()
# Out:
# Mann-Whitney U Post-Hoc Tests (Bonferroni-corrected alpha = 0.0042)
# ...
#  Action/Competitive
#      NA vs EU  U =   1410  p = 0.3594
#      NA vs JP  U =   1483  p = 0.0819
#      EU vs JP  U =   1603  p = 0.0101
#
#  Narrative
#      NA vs EU  U =   1584  p = 0.3420
#      NA vs JP  U =    533  p = 0.0000   [SIG]
#      EU vs JP  U =    402  p = 0.0000   [SIG]
#
#  Strategy/Cognitive
#      NA vs EU  U =   1424  p = 0.9702
#      NA vs JP  U =   1140  p = 0.8425
#      EU vs JP  U =   1162  p = 0.8389
#
#  Misc
#      NA vs EU  U =   1533  p = 0.7734
#      NA vs JP  U =   1283  p = 0.3774
#      EU vs JP  U =   1274  p = 0.5124

# %% [markdown]
# #### 1.4 Monte Carlo Simulation - Are Regional Differences Due to Chance?
#
# We test the null hypothesis (no region differences) by randomly permuting sales across regions 10,000 times per genre. The observed variance across regional mean shares is compared to the permuted null distribution to compute an empirical p-value

# %%
np.random.seed(42)
N_SIM = 10_000
mc_results = {}

for genre in GENRES:
    sub = agg_vg[agg_vg['Genre_Cat'] == genre].copy()
    na = sub['NA_Share'].dropna().values
    eu = sub['EU_Share'].dropna().values
    jp = sub['JP_Share'].dropna().values
    obs_means = np.array([na.mean(), eu.mean(), jp.mean()])
    obs_var   = np.var(obs_means)
    all_shares = np.concatenate([na, eu, jp])
    n = len(all_shares) // 3
    sim_vars = []
    for _ in range(N_SIM):
        s = np.random.choice(all_shares, size=3*n, replace=True)
        sim_vars.append(np.var([s[:n].mean(), s[n:2*n].mean(), s[2*n:].mean()]))
    sim_vars = np.array(sim_vars)
    p_mc = (sim_vars >= obs_var).mean()
    mc_results[genre] = {'obs_var': obs_var, 'sim_vars': sim_vars, 'p_mc': p_mc}

print('Monte Carlo Results (10,000 bootstrap simulations per genre)')
print('=' * 68)
for genre, res in mc_results.items():
    sig = 'Significant' if res['p_mc'] < 0.05 else 'Not significant'
    print(f'{genre:<25}  obs_var = {res["obs_var"]:.6f}   MC p = {res["p_mc"]:.4f}   -> {sig}')
# Out:
# Monte Carlo Results (10,000 bootstrap simulations per genre)
# ...
# Action/Competitive         obs_var = 0.002621   MC p = 0.0513   -> Not significant
# Narrative                  obs_var = 0.006846   MC p = 0.0000   -> Significant
# Strategy/Cognitive         obs_var = 0.000593   MC p = 0.1777   -> Not significant
# Misc                       obs_var = 0.000045   MC p = 0.9161   -> Not significant

# %%
fig, axes = plt.subplots(2, 2, figsize=(13, 9))
for ax, (genre, res), color in zip(axes.flatten(), mc_results.items(), GENRE_COLORS):
    ax.hist(res['sim_vars'], bins=60, color=color, alpha=0.7, edgecolor='white', label='Simulated null')
    ax.axvline(res['obs_var'], color='black', linewidth=2, linestyle='--',
               label=f'Observed  (MC p = {res["p_mc"]:.4f})')
    ax.set_title(genre)
    ax.set_xlabel('Variance of regional mean shares')
    ax.set_ylabel('Frequency')
    ax.legend(fontsize=8)
plt.suptitle('Monte Carlo Simulation: Observed vs Null Distribution of Regional Variance (10,000 sims)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.5 OLS Regression - Has the Regional Gap Changed Over Time?
#
# The EDA showed visually that regional differences appear stable over 2006-2015. Here we formally test this by regressing the maximum pairwise regional gap in genre share on year.
#
# - HO (our hypothesis): Slope = 0 - the region gap has not changed over time
# - Slope > 0: gap is widening (regions diverging)
# - Slope < 0: gap is narrowing (regions converging)
# - p > 0.05: consistent with the hypothesis that the gap is unchanged

# %%
# Annual mean genre share per region (year-weighted, not sales-weighted)
yearly = agg_vg.groupby(['Year', 'Genre_Cat']).agg(
    NA=('NA_Share', 'mean'),
    EU=('EU_Share', 'mean'),
    JP=('JP_Share', 'mean')
).reset_index()

# Max pairwise absolute gap across 3 regions per year-genre
yearly['gap_NA_EU'] = (yearly['NA'] - yearly['EU']).abs()
yearly['gap_NA_JP'] = (yearly['NA'] - yearly['JP']).abs()
yearly['gap_EU_JP'] = (yearly['EU'] - yearly['JP']).abs()
yearly['max_gap']   = yearly[['gap_NA_EU', 'gap_NA_JP', 'gap_EU_JP']].max(axis=1)

print('OLS Regression: Max Regional Genre Share Gap ~ Year')
print('=' * 72)
ols_results = {}
for genre in GENRES:
    sub = yearly[yearly['Genre_Cat'] == genre].sort_values('Year')
    slope, intercept, r, p, se = stats.linregress(sub['Year'].values, sub['max_gap'].values)
    ols_results[genre] = {
        'slope': slope, 'intercept': intercept,
        'r2': r**2, 'p': p,
        'x': sub['Year'].values, 'y': sub['max_gap'].values
    }
    trend = 'widening' if slope > 0 else 'narrowing'
    sig = '(p < 0.05) gap IS changing' if p < 0.05 else '(p > 0.05) gap unchanged'
    print(f'{genre:<25}  slope = {slope:+.5f}   R2 = {r**2:.3f}   p = {p:.4f}   -> {trend}  {sig}')

print()
print('Hypothesis predicts p > 0.05 (no significant change) for all genres.')
# Out:
# OLS Regression: Max Regional Genre Share Gap ~ Year
# ...
# Action/Competitive         slope = +0.01229   R2 = 0.254   p = 0.1379   -> widening  (p > 0.05) gap unchanged
# Narrative                  slope = -0.00211   R2 = 0.008   p = 0.8011   -> narrowing  (p > 0.05) gap unchanged
# Strategy/Cognitive         slope = +0.00412   R2 = 0.089   p = 0.4029   -> widening  (p > 0.05) gap unchanged
# Misc                       slope = +0.01741   R2 = 0.382   p = 0.0568   -> widening  (p > 0.05) gap unchanged
#
# Hypothesis predicts p > 0.05 (no significant change) for all genres.

# %%
fig, axes = plt.subplots(2, 2, figsize=(13, 9))
for ax, (genre, res), color in zip(axes.flatten(), ols_results.items(), GENRE_COLORS):
    x, y = res['x'], res['y']
    ax.scatter(x, y, color=color, s=60, zorder=3, label='Observed max gap')
    ax.plot(x, res['slope']*x + res['intercept'], color='black', linewidth=1.8,
            linestyle='--', label=f'OLS  slope = {res["slope"]:+.5f}')    
    ax.set_title(genre)
    ax.set_xlabel('Year')
    ax.set_ylabel('Max regional gap in share')
    ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
    ax.legend(fontsize=8)
    ax.text(0.05, 0.92, f'R2 = {res["r2"]:.3f} p = {res["p"]:.3f}', transform=ax.transAxes, fontsize=8, color='grey')

plt.suptitle('OLS Regression: Regional Genre Share Gap Over Time (2006-2015)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2 Steam Games Analysis
#
# Steam provides a window into the PC digital market across the same 2006-2015 period. Because there is no region breakdown, we cannot test the regional hypothesis here. Instead, we test whether genre predicts ownership tier, contextualizing whether genre popularity patterns seen in the console data also hold in the PC digital market.
#
# > **Limitation acknowledged in EDA:** Steam ownership data is given as ranges, not exact figures. Supported langauges was considered a regional proxy but deemed insufficiently relaible.

# %% [markdown]
# #### 2.1 Load Processed Steam Data

# %%
df_steam = pd.read_csv('data/02-processed/steamgames_clean.csv')
df_steam = df_steam[df_steam['Year'].between(2006, 2015)].copy()

# Parse ownership ranges to numeric midpoint
def parse_owners(s):
    try:
        lo, hi = [int(x.strip().replace(',', '')) for x in str(s).split('-')]
        return (lo + hi) / 2
    except:
        return np.nan

df_steam['Owners_Mid'] = df_steam['Estimated owners'].apply(parse_owners)

# Ordinal ownership tier
OWNER_ORDER = ['0 - 20000', '20000 - 50000', '50000 - 100000', '100000 - 200000', 
               '200000 - 500000', '500000 - 1000000', '1000000 - 2000000', 
               '2000000 - 5000000', '5000000 - 10000000', '10000000 - 20000000', 
               '20000000 - 50000000', '50000000 - 100000000', '100000000 - 200000000']
df_steam['Owner_Tier'] = pd.Categorical(df_steam['Estimated owners'], categories=OWNER_ORDER, ordered=True)
df_steam['Owner_Rank'] = df_steam['Owner_Tier'].cat.codes

# Mapp primary genre to the same 4 categories used in Part 1
def map_steam_genre(g):
    g = str(g).split(',')[0].strip()
    mapping = {
        'Action': 'Action/Competitive', 'Sports': 'Action/Competitive',
        'Racing': 'Action/Competitive', 'Fighting': 'Action/Competitive',
        'Adventure': 'Narrative', 'RPG': 'Narrative',
        'Strategy': 'Strategy/Cognitive', 'Puzzle': 'Strategy/Cognitive',
        'Simulation': 'Strategy/Cognitive',
        'Indie': 'Misc', 'Casual': 'Misc', 'Free To Play': 'Misc',
        'Early Access': 'Misc', 'Massively Multiplayer': 'Misc'
    }
    return mapping.get(g, 'Misc')

df_steam['Genre_Cat'] = df_steam['Genres'].apply(map_steam_genre)

print(f'Steam -- {df_steam.shape[0]:,} rows (2006-2015)')
print('Genre category distribution:')
print(df_steam['Genre_Cat'].value_counts())
df_steam.head()
# Out:
# Steam -- 5,758 rows (2006-2015)
# Genre category distribution:
# Genre_Cat
# Action/Competitive    2594
# Misc                  1352
# Narrative             1320
# Strategy/Cognitive     492
# Name: count, dtype: int64
#                                                 Name  Year  Estimated owners  \
# 0                                            Redline  2014         0 - 20000
# 1                                         Epic Arena  2015   100000 - 200000
# 2                              New kind of adventure  2015  500000 - 1000000
# 3  March of Industry: Very Capitalist Factory Sim...  2015         0 - 20000
# 4                        My Lands: Black Gem Hunting  2014  500000 - 1000000
#
#                                  Supported languages  \
# 0                                        ['English']
# 1  ['English', 'German', 'Russian', 'Ukrainian', ...
# 2                                        ['English']
# 3  ['English', 'French', 'Italian', 'German', 'Sp...
# ...

# %% [markdown]
# #### 2.2 Chi-Square Test - Does Genre Predict Ownership Tier on Steam?

# %%
median_rank_s = df_steam['Owner_Rank'].median()
df_steam['Ownership_Level'] = np.where(df_steam['Owner_Rank'] >= median_rank_s, 'High', 'Low')

ct_steam = pd.crosstab(df_steam['Genre_Cat'], df_steam['Ownership_Level']).reindex(GENRES).dropna()
print('Contingency table -- Genre vs Ownership Level (Steam):')
print(ct_steam)
print()

chi2_s, p_s, dof_s, _ = chi2_contingency(ct_steam)
n_s = ct_steam.values.sum()
cramers_v_s = np.sqrt(chi2_s / (n_s * (min(ct_steam.shape) - 1)))
effect_s = 'negligible' if cramers_v_s < 0.1 else 'small' if cramers_v_s < 0.3 else 'medium' if cramers_v_s < 0.5 else 'large'

print(f'Chi-Square : {chi2_s:.4f}')
print(f'p-value    : {p_s:.4f}')
print(f"Cramer's V : {cramers_v_s:.4f}  ({effect_s} effect size)")
print()
print('Genre significantly predicts ownership tier on Steam.' if p_s < 0.05
      else 'No significant relationship between genre and ownership tier on Steam.')
# Out:
# Contingency table -- Genre vs Ownership Level (Steam):
# Ownership_Level     High   Low
# Genre_Cat
# Action/Competitive  1561  1033
# Narrative            742   578
# Strategy/Cognitive   291   201
# Misc                 610   742
#
# Chi-Square : 84.9052
# p-value    : 0.0000
# Cramer's V : 0.1214  (small effect size)
#
# Genre significantly predicts ownership tier on Steam.

# %% [markdown]
# #### 2.3 Monte Carlo Simulation - Genre Ownership Rank on Steam

# %%
np.random.seed(42)
N_SIM = 10_000
mc_steam = {}

for genre in GENRES:
    sub = df_steam[df_steam['Genre_Cat'] == genre]['Owner_Rank'].dropna().values
    rest = df_steam[df_steam['Genre_Cat'] != genre]['Owner_Rank'].dropna().values
    if len(sub) < 5:
        continue
    obs_diff = sub.mean() - rest.mean()
    combined = np.concatenate([sub, rest])
    n = len(sub)
    sim_diffs = []
    for _ in range(N_SIM):
        perm = np.random.permutation(combined)
        sim_diffs.append(perm[:n].mean() - perm[n:].mean())
    sim_diffs = np.array(sim_diffs)
    p_mc_s = (np.abs(sim_diffs) >= np.abs(obs_diff)).mean()
    mc_steam[genre] = {'obs_diff': obs_diff, 'sim_diffs': sim_diffs, 'p_mc': p_mc_s}

print('Monte Carlo: Does each genre have significantly different ownership rank vs all others?')
print('=' * 72)
for genre, res in mc_steam.items():
    direction = 'above' if res['obs_diff'] > 0 else 'below'
    sig = 'Significant' if res['p_mc'] < 0.05 else 'Not significant'
    print(f'{genre:<25} obs_diff = {res["obs_diff"]:+.3f} ({direction} avg)   MC p = {res["p_mc"]:.4f}  -> {sig}')
# Out:
# Monte Carlo: Does each genre have significantly different ownership rank vs all others?
# ...
# Action/Competitive        obs_diff = +0.582 (above avg)   MC p = 0.0000  -> Significant
# Narrative                 obs_diff = -0.203 (below avg)   MC p = 0.0013  -> Significant
# Strategy/Cognitive        obs_diff = +0.158 (above avg)   MC p = 0.1008  -> Not significant
# Misc                      obs_diff = -0.671 (below avg)   MC p = 0.0000  -> Significant

# %%
fig, axes = plt.subplots(2, 2, figsize=(13, 9))
for ax, (genre, res), color in zip(axes.flatten(), mc_steam.items(), GENRE_COLORS):
    ax.hist(res['sim_diffs'], bins=60, color=color, alpha=0.7, edgecolor='white', label='Permuted null')
    ax.axvline(res['obs_diff'], color='black', linewidth=2, linestyle='--',
               label=f'Observed  (MC p = {res["p_mc"]:.4f})')
    ax.set_title(f'Steam -- {genre}')
    ax.set_xlabel('Mean ownership rank difference')
    ax.set_ylabel('Frequency')
    ax.legend(fontsize=8)

plt.suptitle('Steam Monte Carlo: Genre Ownership Rank vs Permuted Null (10,000 sims)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2.4 Steam Genre Trends Over Time (2006-2015)

# %%
yearly_steam = df_steam.groupby(['Year', 'Genre_Cat']).size().reset_index(name='Count')
total_per_year = yearly_steam.groupby('Year')['Count'].transform('sum')
yearly_steam['Share'] = yearly_steam['Count'] / total_per_year

fig, ax = plt.subplots(figsize=(12, 5))
for genre, color in zip(GENRES, GENRE_COLORS):
    sub = yearly_steam[yearly_steam['Genre_Cat'] == genre].sort_values('Year')
    ax.plot(sub['Year'], sub['Share'], marker='o', label=genre, color=color, linewidth=2)

ax.set_title('Steam -- Genre Share of New Releases Over Time (2006-2015)')
ax.set_xlabel('Year')
ax.set_ylabel('Share of Annual Releases')
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
ax.set_xticks(range(2006, 2016))
ax.set_xticklabels(range(2006, 2016), rotation=45)
ax.legend(title='Genre')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3 Google Play Store
#
# The Google Play dataset represents the mobile gaming market. As noted in the EDA, it has no year column and no regional breakdown. It is used here to test whether genre predicts install tier on mobile - providing cross-platform context for genre popularity patterns.
#
# > **Limitation (from EDA):** No temporal or regional data avaliable. Results are purely cross-sectional and specitic to the mobile paltform.

# %% [markdown]
# #### 3.1 Load Processed Google Play Data

# %%
df_gp = pd.read_csv('data/02-processed/googleplaystore_clean.csv')

def parse_installs(s):
    s = str(s).replace(',', '').replace('+', '').strip()
    try:
        return float(s)
    except:
        return np.nan

df_gp['Installs_Num'] = df_gp['Installs'].apply(parse_installs)
df_gp = df_gp.dropna(subset=['Installs_Num'])

install_order = ['1+', '5+', '10+', '50+', '100+', '500+', '1,000+', '5,000+', '10,000+',
                 '50,000+', '100,000+', '500,000+', '1,000,000+', '5,000,000+', '10,000,000+',
                 '50,000,000+', '100,000,000+', '500,000,000+', '1,000,000,000+']
df_gp['Install_Tier'] = pd.Categorical(df_gp['Installs'], categories=install_order, ordered=True)
df_gp['Install_Rank'] = df_gp['Install_Tier'].cat.codes

def map_gp_genre(g):
    g = str(g).split(';')[0].strip()
    mapping = {
        'Action': 'Action/Competitive', 'Action & Adventure': 'Action/Competitive',
        'Sports': 'Action/Competitive', 'Racing': 'Action/Competitive', 'Adventure': 'Narrative',
        'Role Playing': 'Narrative', 'Strategy': 'Strategy/Cognitive', 'Simulation': 'Strategy/Cognitive',
        'Puzzle': 'Strategy/Cognitive', 'Brain Games': 'Strategy/Cognitive', 'Arcade': 'Misc', 'Casual': 'Misc',
        'Card': 'Misc', 'Board': 'Misc', 'Music': 'Misc', 'Trivia': 'Misc', 'Word': 'Misc'
    }
    return mapping.get(g, 'Misc')

df_gp['Genre_Cat'] = df_gp['Genres'].apply(map_gp_genre)

print(f'Google Play -- {df_gp.shape[0]:,} rows')
print('Genre category distribution:')
print(df_gp['Genre_Cat'].value_counts())
df_gp.head()
# Out:
# Google Play -- 1,144 rows
# Genre category distribution:
# Genre_Cat
# Misc                  489
# Action/Competitive    480
# Narrative              96
# Strategy/Cognitive     79
# Name: count, dtype: int64
#                 App        Installs                        Genres  \
# 0            ROBLOX    100,000,000+  Adventure;Action & Adventure
# 1    Subway Surfers  1,000,000,000+                        Arcade
# 2  Candy Crush Saga    500,000,000+                        Casual
# 3         Solitaire     10,000,000+                          Card
# 4    Bubble Shooter     10,000,000+                        Casual
#
#    Installs_Num    Install_Tier  Install_Rank  Genre_Cat
# 0  1.000000e+08    100,000,000+            16  Narrative
# 1  1.000000e+09  1,000,000,000+            18       Misc
# 2  5.000000e+08    500,000,000+            17       Misc
# 3  1.000000e+07     10,000,000+            14       Misc
# 4  1.000000e+07     10,000,000+            14       Misc

# %% [markdown]
# #### 3.2 Chi-Square Test - Does Genre Predict Install Tier on Google Play?

# %%
median_rank_gp = df_gp['Install_Rank'].median()
df_gp['Install_Level'] = np.where(df_gp['Install_Rank'] >= median_rank_gp, 'High', 'Low')

ct_gp = pd.crosstab(df_gp['Genre_Cat'], df_gp['Install_Level']).reindex(GENRES).dropna()
print('Contingency table -- Genre vs Install Level (Google Play):')
print(ct_gp)
print()

chi2_gp, p_gp, dof_gp, _ = chi2_contingency(ct_gp)
n_gp = ct_gp.values.sum()
cramers_v_gp = np.sqrt(chi2_gp / (n_gp * (min(ct_gp.shape) - 1)))
effect_gp = 'negligible' if cramers_v_gp < 0.1 else 'small' if cramers_v_gp < 0.3 else 'medium' if cramers_v_gp < 0.5 else 'large'

print(f'Chi-Square : {chi2_gp:.4f}')
print(f'p-value    : {p_gp:.4f}')
print(f"Cramer's V : {cramers_v_gp:.4f}  ({effect_gp} effect size)")
print()
print('Genre significantly predicts install tier on Google Play.' if p_gp < 0.05
      else 'No significant relationship between genre and install tier on Google Play.')
# Out:
# Contingency table -- Genre vs Install Level (Google Play):
# Install_Level       High  Low
# Genre_Cat
# Action/Competitive   334  146
# Narrative             48   48
# Strategy/Cognitive    72    7
# Misc                 283  206
#
# Chi-Square : 48.0446
# p-value    : 0.0000
# Cramer's V : 0.2049  (small effect size)
#
# Genre significantly predicts install tier on Google Play.

# %% [markdown]
# #### 3.3 Monte Carlo Simulation - Genre Install Rank on Google Play

# %%
np.random.seed(42)
mc_gp = {}

for genre in GENRES:
    sub = df_gp[df_gp['Genre_Cat'] == genre]['Install_Rank'].dropna().values
    rest = df_gp[df_gp['Genre_Cat'] != genre]['Install_Rank'].dropna().values
    if len(sub) < 5:
        continue
    obs_diff = sub.mean() - rest.mean()
    combined = np.concatenate([sub, rest])
    n = len(sub)
    sim_diffs = []
    for _ in range(N_SIM):
        perm = np.random.permutation(combined)
        sim_diffs.append(perm[:n].mean() - perm[n:].mean())
    sim_diffs = np.array(sim_diffs)
    p_mc_gp = (np.abs(sim_diffs) >= np.abs(obs_diff)).mean()
    mc_gp[genre] = {'obs_diff': obs_diff, 'sim_diffs': sim_diffs, 'p_mc': p_mc_gp}

print('Monte Carlo: Does each genre have significantly different install rank vs all others?')
print('=' * 72)
for genre, res in mc_gp.items():
    direction = 'above' if res['obs_diff'] > 0 else 'below'
    sig = 'Significant' if res['p_mc'] < 0.05 else 'Not significant'
    print(f'{genre:<25} obs_diff = {res["obs_diff"]:+.3f} ({direction} avg)  MC p = {res["p_mc"]:.4f}  -> {sig}')
# Out:
# Monte Carlo: Does each genre have significantly different install rank vs all others?
# ...
# Action/Competitive        obs_diff = +0.722 (above avg)  MC p = 0.0006  -> Significant
# Narrative                 obs_diff = -0.946 (below avg)  MC p = 0.0120  -> Significant
# Strategy/Cognitive        obs_diff = +2.142 (above avg)  MC p = 0.0000  -> Significant
# Misc                      obs_diff = -0.984 (below avg)  MC p = 0.0000  -> Significant

# %%
fig, axes = plt.subplots(2, 2, figsize=(13, 9))
for ax, (genre, res), color in zip(axes.flatten(), mc_gp.items(), GENRE_COLORS):
    ax.hist(res['sim_diffs'], bins=60, color=color, alpha=0.7, edgecolor='white', label='Permuted null')
    ax.axvline(res['obs_diff'], color='black', linewidth=2, linestyle='--',
                label=f'Observed  (MC p = {res["p_mc"]:.4f})')
    ax.set_title(f'Google Play -- {genre}')
    ax.set_xlabel('Mean Install rank difference')
    ax.set_ylabel('Frequency')
    ax.legend(fontsize=8)

plt.suptitle('Google Play Montel Carlo: Genre Install Rank vs Permuted Null (10,000 sims)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part 4 - Cross-Platform Genre Comparison
#
# We compare genre composition across all three platform types to contextualize whether the genre preferences seen in regional console data are consistent with the broader PC and mobile markets.

# %%
vg_shares = df_vg['Genre_Cat'].value_counts(normalize=True).reindex(GENRES)
st_shares = df_steam['Genre_Cat'].value_counts(normalize=True).reindex(GENRES)
gp_shares = df_gp['Genre_Cat'].value_counts(normalize=True).reindex(GENRES)

cross = pd.DataFrame({
    'Console/Handheld (VG Sales)': vg_shares,
    'PC Digital (Steam)': st_shares,
    'Mobile (Google Play)': gp_shares
})

print('Genre share by platform type (proportion of titles in each category):')
print(cross.round(3))
# Out:
# Genre share by platform type (proportion of titles in each category):
#                     Console/Handheld (VG Sales)  PC Digital (Steam)  \
# Genre_Cat
# Action/Competitive                        0.503               0.451
# Narrative                                 0.180               0.229
# Strategy/Cognitive                        0.155               0.085
# Misc                                      0.161               0.235
#
#                     Mobile (Google Play)
# Genre_Cat
# Action/Competitive                 0.420
# Narrative                          0.084
# Strategy/Cognitive                 0.069
# Misc                               0.427

# %%
fig, ax = plt.subplots(figsize=(12, 6))
x = np.arange(len(GENRES))
w = 0.25
platform_colors = ['#1565C0', '#2E7D32', '#B71C1C']
for i, (col, color) in enumerate(zip(cross.columns, platform_colors)):
    bars = ax.bar(x + i*w, cross[col].values, width=w, label=col, color=color, alpha=0.85, edgecolor='white')
    for bar, val in zip(bars, cross[col].values):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.003, f'{val:.0%}', ha='center', va='bottom', fontsize=7)

ax.set_xticks(x + w)
ax.set_xticklabels(GENRES, fontsize=10)
ax.set_ylabel('Share of Titles')
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
ax.set_title('Genre Distribution Across Platform Types\nConsole/Handheld vs PC Digital vs Mobile')
ax.legend(title='Platform')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > There are no human subjects.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > There is potentially a bias in the video game data collected in our source dataset, so we can cross reference a couple of other datasets in case we are missing information.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > We do not collect any information that is not relevant for analysis, so there is no personally identifiable information at all in our data.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > We do not have control over the ways our dataset collected information, but in measuring sales of a video game, the factual data has no race or gender to discriminate.
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > Our data is open-sourced on Kaggle.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > Our datasets include no personal information.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > We will delete the data after our research study, as it will no longer be needed.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Due to the limited time and nature of this experiment, we do not plan to consult subject matter experts.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We have examined the data for possible sources of bias and have outlined our concerns in the initial cleaning; further action TBD.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > To the best of our ability, yes.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > We have no PII.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > Yes.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > Yes.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > Yes.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > Yes, we understand that optimizing the data means losing some information and affecting data wrangling.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > Yes, notes have been made on datasets to explain why some parts of the data cannot be used or does not support the hypothesis.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > Yes, to the best of our ability.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
